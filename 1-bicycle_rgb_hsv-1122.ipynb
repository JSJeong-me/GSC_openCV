# %% [markdown]
# <a href="https://colab.research.google.com/github/JSJeong-me/GSC_openCV/blob/main/1-bicycle_rgb_hsv-1122.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from google.colab.patches import cv2_imshow

# %%
cv2.__version__
# Out:
# '4.6.0'

# %%
src = cv2.imread('./bicycle.png', cv2.IMREAD_UNCHANGED)

# %%
src.shape
# Out:
# (1534, 2045, 4)

# %%
src_rgb = cv2.cvtColor(src, cv2.COLOR_BGR2RGB)

# %%
src_rgb = cv2.resize(src_rgb, (0,0), fx=0.3, fy=0.3)

# %%
cv2_imshow(src_rgb)
# Out:
# <PIL.Image.Image image mode=RGB size=614x460 at 0x7F59C39A11D0>

# %%
cv2_imshow(src)
# Out:
# <PIL.Image.Image image mode=RGBA size=2045x1534 at 0x7F59C52FFCD0>

# %% [markdown]
# high_yellow[255, 213, 58]
# low_yellow[221, 195, 5]

# %%
import numpy as np

# %%
low_yellow = np.array([221, 195, 5])
high_yellow = np.array([255, 213, 58])

# %%
mask = cv2.inRange(src_rgb, low_yellow, high_yellow)

# %%
result_src = cv2.bitwise_and(src, src, mask = mask)

# %%
cv2_imshow(result_src)
# Out:
# <PIL.Image.Image image mode=RGBA size=2045x1534 at 0x7F08EB2B0290>

# %%
low_yellow = np.array([40, 0, 0])
high_yellow = np.array([255, 255, 255])

# %%
src_rgb = cv2.cvtColor(src, cv2.COLOR_BGR2RGB)

# %%
src_hsv = cv2.cvtColor(src_rgb, cv2.COLOR_RGB2HSV)

# %%
mask = cv2.inRange(src_hsv, low_yellow, high_yellow)

# %%
result_src = cv2.bitwise_and(src, src, mask = mask)

# %%
cv2_imshow(result_src)
# Out:
# <PIL.Image.Image image mode=RGBA size=2045x1534 at 0x7FD81AE5B3D0>
